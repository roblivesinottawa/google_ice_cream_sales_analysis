# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
df = pd.read_excel("../data/B3ofmLtERPq6H5i7RFT6Pg_1ca5eec9c08941518e2c16034a2e65f1_SalesByDay.xlsx")

# %%
df.to_csv("../data/SalesByDay.csv", index=None, header=True)

# %%
df = pd.read_csv("../data/SalesByDay.csv")

# %%
df.head()
# Out:
#          date    sales
# 0  2019-01-01  59.9622
# 1  2019-01-02  67.0605
# 2  2019-01-03  74.2350
# 3  2019-01-04  78.1120
# 4  2019-01-05  84.7636

# %%
df1 = pd.read_excel('../data/DHN9hYWCSDCzfYWFgvgwgg_b0e0d35f6a4f4bde9c84ecd0dd69c0f1_SalesByFlavor.xlsx')

# %%
df1.to_csv('../data/SalesByFlavor.csv', index=None, header=True)

# %%
df2 = pd.read_excel('../data/jmigEulNR7yooBLpTYe8Cw_9ecaf818f1a74b7987fe6a7d9af3c1f1_SalesByTemp.xlsx')

# %%
df2.to_csv('../data/SalesByTemp.csv', index=None, header=True)

# %%
df
# Out:
#            date     sales
# 0    2019-01-01   59.9622
# 1    2019-01-02   67.0605
# 2    2019-01-03   74.2350
# 3    2019-01-04   78.1120
# 4    2019-01-05   84.7636
# ..          ...       ...
# 360  2019-12-27  120.9601
# 361  2019-12-28  143.6813
# 362  2019-12-29  155.2061
# 363  2019-12-30  169.2145
# 364  2019-12-31  165.2011
#
# [365 rows x 2 columns]

# %%
df1
# Out:
#      week  units sold      flavor
# 0       1           6   chocolate
# 1       1          15       lemon
# 2       1          12  strawberry
# 3       1           6     vanilla
# 4       2          16   chocolate
# ..    ...         ...         ...
# 203    51          20     vanilla
# 204    52          10   chocolate
# 205    52           9       lemon
# 206    52           1  strawberry
# 207    52          18     vanilla
#
# [208 rows x 3 columns]

# %%
df2
# Out:
#      temperature      sales
# 0      60.217676  39.693565
# 1      80.372455  61.592665
# 2      57.674373  33.443372
# 3      95.800183  80.020249
# 4      95.170632  80.754129
# ..           ...        ...
# 360    49.608285  22.890103
# 361    88.542732  73.159822
# 362    80.939331  64.234981
# 363    73.167012  55.005522
# 364    69.682294  49.945834
#
# [365 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['date', 'sales'], dtype='object')

# %%
df.date
# Out:
# 0      2019-01-01
# 1      2019-01-02
# 2      2019-01-03
# 3      2019-01-04
# 4      2019-01-05
#           ...
# 360    2019-12-27
# 361    2019-12-28
# 362    2019-12-29
# 363    2019-12-30
# 364    2019-12-31
# Name: date, Length: 365, dtype: object

# %%
df['sales']
# Out:
# 0       59.9622
# 1       67.0605
# 2       74.2350
# 3       78.1120
# 4       84.7636
#          ...
# 360    120.9601
# 361    143.6813
# 362    155.2061
# 363    169.2145
# 364    165.2011
# Name: sales, Length: 365, dtype: float64

# %%
df[df.sales > 100].value_counts()
# Out:
# date        sales
# 2019-01-06  100.5960    1
# 2019-09-04  147.0626    1
# 2019-10-07  150.0524    1
# 2019-10-08  148.7095    1
# 2019-10-09  174.4632    1
#                        ..
# 2019-07-25  104.3502    1
# 2019-07-26  115.4340    1
# 2019-07-27  121.1818    1
# 2019-07-28  126.1014    1
# 2019-12-31  165.2011    1
# Length: 193, dtype: int64

# %%
df.groupby('date').sales.sum()
# Out:
# date
# 2019-01-01     59.9622
# 2019-01-02     67.0605
# 2019-01-03     74.2350
# 2019-01-04     78.1120
# 2019-01-05     84.7636
#                 ...
# 2019-12-27    120.9601
# 2019-12-28    143.6813
# 2019-12-29    155.2061
# 2019-12-30    169.2145
# 2019-12-31    165.2011
# Name: sales, Length: 365, dtype: float64

# %%
# not good example
sns.lineplot(x='sales', y='date', data=df)
# Out:
# <AxesSubplot:xlabel='sales', ylabel='date'>

# %%
plt.figure(figsize=(10, 6))
df.plot(x='date', y='sales', kind='line')
plt.xticks(rotation=45)
plt.show()

# %%
df1
# Out:
#      week  units sold      flavor
# 0       1           6   chocolate
# 1       1          15       lemon
# 2       1          12  strawberry
# 3       1           6     vanilla
# 4       2          16   chocolate
# ..    ...         ...         ...
# 203    51          20     vanilla
# 204    52          10   chocolate
# 205    52           9       lemon
# 206    52           1  strawberry
# 207    52          18     vanilla
#
# [208 rows x 3 columns]

# %%
# most popular flavor
df1.groupby('flavor')['units sold'].sum().sort_values(ascending=False).head(1)
# Out:
# flavor
# lemon    713
# Name: units sold, dtype: int64

# %%
df2
# Out:
#      temperature      sales
# 0      60.217676  39.693565
# 1      80.372455  61.592665
# 2      57.674373  33.443372
# 3      95.800183  80.020249
# 4      95.170632  80.754129
# ..           ...        ...
# 360    49.608285  22.890103
# 361    88.542732  73.159822
# 362    80.939331  64.234981
# 363    73.167012  55.005522
# 364    69.682294  49.945834
#
# [365 rows x 2 columns]

# %%
sns.lineplot(x='temperature', y='sales', data=df2)
# Out:
# <AxesSubplot:xlabel='temperature', ylabel='sales'>

# %%
df2.plot(x='temperature', y='sales', kind='line')
# Out:
# <AxesSubplot:xlabel='temperature'>

# %%
df.head()
# Out:
#          date    sales
# 0  2019-01-01  59.9622
# 1  2019-01-02  67.0605
# 2  2019-01-03  74.2350
# 3  2019-01-04  78.1120
# 4  2019-01-05  84.7636

# %%
df1.head()
# Out:
#    week  units sold      flavor
# 0     1           6   chocolate
# 1     1          15       lemon
# 2     1          12  strawberry
# 3     1           6     vanilla
# 4     2          16   chocolate

# %%
# combine dataframes
df_combined = pd.concat([df, df1, df2], axis=1)

# %%
df_combined.head()
# Out:
#          date    sales  week  units sold      flavor  temperature      sales
# 0  2019-01-01  59.9622   1.0         6.0   chocolate    60.217676  39.693565
# 1  2019-01-02  67.0605   1.0        15.0       lemon    80.372455  61.592665
# 2  2019-01-03  74.2350   1.0        12.0  strawberry    57.674373  33.443372
# 3  2019-01-04  78.1120   1.0         6.0     vanilla    95.800183  80.020249
# 4  2019-01-05  84.7636   2.0        16.0   chocolate    95.170632  80.754129

# %%
df_combined.columns
# Out:
# Index(['date', 'sales', 'week', 'units sold', 'flavor', 'temperature',
#        'sales'],
#       dtype='object')

# %%
df_combined.plot(x='date', y='sales', kind='line', legend=True, title='Sales by Date', figsize=(10, 6), grid=True, fontsize=12)
# Out:
# <AxesSubplot:title={'center':'Sales by Date'}, xlabel='date'>
